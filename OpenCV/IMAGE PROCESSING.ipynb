# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img  = cv2.imread('frame0.jpg')

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.imshow(img)

# %%
####################BLENDING AND PASTING IMAGES###############################

# %%
img1 = cv2.imread('frame0.jpg')
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB) 
img2 = cv2.imread('frame4.jpg')
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
############this image are of same size IF NOT RESIZE  IT#######################
#img1 = cv2.resize(img1,(1200,1200))
#img2 = cv2.resize(img2,(1200,1200))

# %%
##############BLENDING IMAGE OF SAME SIZE######################

# %%
img1.shape, img2.shape
# Out:
# ((720, 1280, 3), (720, 1280, 3))

# %%
blended = cv2.addWeighted(src1 = img1,src2 = img2, alpha = 0.5, beta = 0.5, gamma = 0)
plt.imshow(blended) ##ADDWEIGHTED WORK FOR ONLY SAME SIZE IMAGE

# %%
blended = cv2.addWeighted(src1 = img1,src2 = img2, alpha = 1, beta = 0.5, gamma = 0)
plt.imshow(blended)

# %%
blended = cv2.addWeighted(src1 = img1,src2 = img2, alpha = 0.5, beta = 1, gamma = 0)
plt.imshow(blended)

# %%
blended = cv2.addWeighted(src1 = img1,src2 = img2, alpha = 1, beta = 1, gamma = 0)
plt.imshow(blended)

# %%
########SMALL IAMHGE ON TOP OF LARGER IMAGE######################(NOBLENDING)
#NUMPY REASSINGNMENT

# %%
img2 = cv2.resize(img2,(600,600))

# %%
plt.imshow(img2)

# %%
plt.imshow(img1)

# %%
large_img = img1
small_img = img2

# %%
x_offset = 0
y_offset = 0

# %%
x_end = x_offset + small_img.shape[1]
y_end = y_offset + small_img.shape[0]

# %%
large_img[y_offset:y_end,x_offset:y_end] = small_img

# %%
plt.imshow(large_img)

# %%
############################IMAGE THRESHOILDING#########################

# %%
img3 = cv2.imread('frame0.jpg',0)

# %%
plt.imshow(img3,cmap  = 'gray')

# %%
ret, thresh1 = cv2.threshold(img3,127,255,cv2.THRESH_BINARY)

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1,cmap = 'gray')  ####all the value 0 or 255######

# %%
ret, thresh1 = cv2.threshold(img3,127,255,cv2.THRESH_BINARY_INV) 
plt.imshow(thresh1,cmap='gray') ####all the value 255 or 0######

# %%
ret, thresh1 = cv2.threshold(img3,127,255,cv2.THRESH_TRUNC) 
plt.imshow(thresh1,cmap='gray') ############middle###########

# %%
#################fig size##############################################
img4 = cv2.imread('frame0.jpg',0)
def show_pic(img4):
    fig = plt.figure(figsize=(15,15))
    ax = fig.add_subplot(111)
    ax.imshow(img4,cmap = 'gray')

# %%
show_pic(img4)

# %%
#########################BLURING AND SMOOTHING###################################

# %%
import numpy  as np

# %%
###########image loading function###################
def load_img():
    img5 = cv2.imread('frame0.jpg').astype(np.float32) / 255
    img5 = cv2.cvtColor(img5,cv2.COLOR_BGR2RGB)
    return img5

# %%
load_img()
# Out:
# array([[[0.        , 0.16862746, 0.        ],
#         [0.5254902 , 0.69803923, 0.5058824 ],
#         [0.6313726 , 0.8039216 , 0.6117647 ],
#         ...,
#         [0.6666667 , 0.79607844, 0.627451  ],
#         [0.5647059 , 0.69411767, 0.5254902 ],
#         [0.02352941, 0.15294118, 0.        ]],
#
#        [[0.        , 0.16862746, 0.        ],
#         [0.5254902 , 0.69803923, 0.5058824 ],
#         [0.6313726 , 0.8039216 , 0.6117647 ],
#         ...,
#         [0.6666667 , 0.79607844, 0.627451  ],
#         [0.5647059 , 0.69411767, 0.5254902 ],
#         [0.02352941, 0.15294118, 0.        ]],
#
#        [[0.        , 0.16862746, 0.        ],
#         [0.5254902 , 0.69803923, 0.5058824 ],
#         [0.6313726 , 0.8039216 , 0.6117647 ],
#         ...,
#         [0.65882355, 0.8       , 0.627451  ],
#         [0.5647059 , 0.69411767, 0.5254902 ],
#         [0.02352941, 0.15294118, 0.        ]],
#
#        ...,
#
#        [[0.02352941, 0.02352941, 0.0627451 ],
# ...

# %%
img5 = cv2.imread('frame0.jpg')
img5 = cv2.cvtColor(img5,cv2.COLOR_BGR2RGB) 
def display_img(img5):
    fig = plt.figure(figsize=(15,15))
    ax = fig.add_subplot(111)
    ax.imshow(img5)

# %%
display_img(img5)

# %%
gamma = 4

# %%
result = np.power(img5,gamma)

# %%
plt.imshow(result)

# %%
gamma = 2
result = np.power(img5,gamma)
plt.imshow(result)

# %%
############BLURING############################

# %%
font = cv2.FONT_HERSHEY_COMPLEX
cv2.putText(img5,text= 'jerry',org=(10,600),fontFace = font,fontScale= 10,color=(255,0,0),thickness = 4)
# Out:
# array([[[  0,  43,   0],
#         [134, 178, 129],
#         [161, 205, 156],
#         ...,
#         [170, 203, 160],
#         [144, 177, 134],
#         [  6,  39,   0]],
#
#        [[  0,  43,   0],
#         [134, 178, 129],
#         [161, 205, 156],
#         ...,
#         [170, 203, 160],
#         [144, 177, 134],
#         [  6,  39,   0]],
#
#        [[  0,  43,   0],
#         [134, 178, 129],
#         [161, 205, 156],
#         ...,
#         [168, 204, 160],
#         [144, 177, 134],
#         [  6,  39,   0]],
#
#        ...,
#
#        [[  6,   6,  16],
#         [ 79,  79,  87],
#         [103, 104, 108],
#         ...,
#         [ 46,  70,  70],
#         [ 47,  67,  66],
#         [  0,  13,  13]],
#
#        [[  6,   6,  16],
#         [ 79,  79,  87],
#         [103, 104, 108],
#         ...,
#         [ 46,  70,  70],
#         [ 47,  67,  66],
#         [  0,  13,  13]],
#
#        [[  6,   6,  16],
#         [ 79,  79,  87],
#         [103, 104, 108],
# ...

# %%
display_img(img5)

# %%
kernal = np.ones(shape=(5,5),dtype = np.float32) / 25

# %%
kernal
# Out:
# array([[0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04]], dtype=float32)

# %%
dst = cv2.filter2D(img5,-1,kernal)
display_img(dst)

# %%
font = cv2.FONT_HERSHEY_COMPLEX
cv2.putText(img5,text= 'jerry',org=(10,600),fontFace = font,fontScale= 10,color=(255,0,0),thickness = 4)
# Out:
# array([[[  0,  43,   0],
#         [134, 178, 129],
#         [161, 205, 156],
#         ...,
#         [170, 203, 160],
#         [144, 177, 134],
#         [  6,  39,   0]],
#
#        [[  0,  43,   0],
#         [134, 178, 129],
#         [161, 205, 156],
#         ...,
#         [170, 203, 160],
#         [144, 177, 134],
#         [  6,  39,   0]],
#
#        [[  0,  43,   0],
#         [134, 178, 129],
#         [161, 205, 156],
#         ...,
#         [168, 204, 160],
#         [144, 177, 134],
#         [  6,  39,   0]],
#
#        ...,
#
#        [[  6,   6,  16],
#         [ 79,  79,  87],
#         [103, 104, 108],
#         ...,
#         [ 46,  70,  70],
#         [ 47,  67,  66],
#         [  0,  13,  13]],
#
#        [[  6,   6,  16],
#         [ 79,  79,  87],
#         [103, 104, 108],
#         ...,
#         [ 46,  70,  70],
#         [ 47,  67,  66],
#         [  0,  13,  13]],
#
#        [[  6,   6,  16],
#         [ 79,  79,  87],
#         [103, 104, 108],
# ...

# %%
 display_img(img5)

# %%
blurred = cv2.blur(img5,ksize=(5,5))
display_img(blurred)

# %%
blurred = cv2.blur(img5,ksize=(10,10))
display_img(blurred)

# %%
mediunblurred = cv2.medianBlur(img5,5)
display_img(mediunblurred) ############to rremove the noise######################

# %%
###################EDGE DETECTION####################################

# %%
img6 = cv2.imread('frame4.jpg',0)
img6 = cv2.cvtColor(img6,cv2.COLOR_BGR2RGB)  
def display_img(img6):
    fig = plt.figure(figsize=(15,15))
    ax = fig.add_subplot(111)
    ax.imshow(img6,cmap='gray')

# %%
display_img(img6)

# %%
sobelx = cv2.Sobel(img6,cv2.CV_64F,1,0,ksize= 5) #horizantal

# %%
display_img(sobelx)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
sobely = cv2.Sobel(img6,cv2.CV_64F,0,1,ksize= 5) #vertical

# %%
display_img(sobely)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
laplacian = cv2.Laplacian(img,cv2.CV_64F) #both

# %%
display_img(laplacian)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
blended = cv2.addWeighted(src1= sobelx,alpha=0.5,src2 =sobely,beta= 0.5,gamma=0) #both with less noice

# %%
display_img(blended)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
